# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data = pd.read_csv('../../applications/wpg-1/data/wpg-1_with_clustered_label.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86710 entries, 0 to 86709
# Data columns (total 17 columns):
# ReportDate             86072 non-null object
# Customer               86678 non-null float64
# Type                   86600 non-null object
# ItemShortName          86678 non-null object
# Brand                  86678 non-null object
# Sales                  45320 non-null object
# AWU_Avial_ratio        86710 non-null float64
# Backlog_Avail_ratio    86710 non-null float64
# Actual_AWU             86710 non-null float64
# Avail                  86710 non-null float64
# BL<=9WKs               86710 non-null float64
# Backlog                86710 non-null float64
# DCOH                   86710 non-null float64
# Hub_OH                 86710 non-null float64
# TTL_OH                 86710 non-null float64
# FCST_M                 82822 non-null float64
# clustered_label        86710 non-null float64
# dtypes: float64(12), object(5)
# memory usage: 11.2+ MB

# %%
mask_231 = data['clustered_label'] == 0.661
print(data[mask_231])
# Out:
# Empty DataFrame
# Columns: [ReportDate, Customer, Type, ItemShortName, Brand, Sales, AWU_Avial_ratio, Backlog_Avail_ratio, Actual_AWU, Avail, BL<=9WKs, Backlog, DCOH, Hub_OH, TTL_OH, FCST_M, clustered_label]
# Index: []

# %%
mask_23 = data['clustered_label'].between(0.23, 0.239)
print(data[mask_23])
# Out:
#              ReportDate  Customer       Type         ItemShortName      Brand  \
# 14225   28/11/2016 3:00   10759.0   ZeroZero     T6WC7XBG-0002(XO)    TOSHIBA
# 14226   28/11/2016 3:00   10759.0  OverStock            ZTM6232DLN    ZILLTEK
# 14227   28/11/2016 3:00   10759.0   ZeroZero            TC90432MBG    TOSHIBA
# 14228   28/11/2016 3:00   10759.0   ZeroZero    TC58BVG2S0FTA00B4H    TOSHIBA
# 14229   28/11/2016 3:00   10759.0       FCST           CM32181A3OP    CAPELLA
# 14230   28/11/2016 3:00   10759.0   ZeroZero    TC58BVG1S3HTA00B4H    TOSHIBA
# 14231   28/11/2016 3:00   10759.0   ZeroZero    TC58NVG0S3HTA00B4H    TOSHIBA
# 14232   28/11/2016 3:00   10759.0   ZeroZero             AXT390124  PANASONIC
# 14233   28/11/2016 3:00   10759.0   ZeroZero  MX25L12835FM2I-10G.T       MXIC
# 14234   28/11/2016 3:00   10759.0   ZeroZero       AXA2R73061S05-M  PANASONIC
# 14235   28/11/2016 3:00   10759.0   ZeroZero             ZTS6031AC    ZILLTEK
# ...

# %%
mask_2 = data['clustered_label'].between(0.2, 0.29)
print(data[mask_2])
# Out:
#              ReportDate  Customer       Type       ItemShortName     Brand  \
# 3462    28/11/2016 3:00   10759.0  OverStock           TC7SZ14FU   TOSHIBA
# 3463   04/09/2016 17:40   10759.0  OverStock      MP20073DH-LF-Z       MPS
# 3464   04/09/2016 17:40   10759.0       FCST     RCLAMP3331ZATFT   SEMTECH
# 3465   04/09/2016 17:40   10759.0  OverStock       SMD1812P110TF      PTTC
# 3466   04/09/2016 17:40   10759.0       FCST           TC7SZ05FU   TOSHIBA
# 3467   04/09/2016 17:40   10759.0  OverStock            TCS40DLR   TOSHIBA
# 3468    29/08/2016 0:03   10759.0       FCST     RCLAMP3331ZATFT   SEMTECH
# 3469    29/08/2016 0:03   10759.0  OverStock       SMD1812P110TF      PTTC
# 3470    29/08/2016 0:03   10759.0       FCST           TC7SZ05FU   TOSHIBA
# 3471    29/08/2016 0:03   10759.0  OverStock          TPCA8059-H   TOSHIBA
# 3472    29/08/2016 0:03   10759.0  OverStock           ZTS6011BV   ZILLTEK
# ...

# %%
fig,axes = plt.subplots()
data[mask_231]['Actual_AWU'].plot(kind='box', ax=axes)
axes.set_ylabel('AWU')
axes.set_xlabel('231')
# Out:
# Text(0.5,0,'231')

# %%
fig,axes = plt.subplots()
data[mask_23]['Actual_AWU'].plot(kind='box', ax=axes)
axes.set_ylabel('AWU')
axes.set_xlabel('23')
# Out:
# Text(0.5,0,'23')

# %%
fig,axes = plt.subplots()
data[mask_2]['Actual_AWU'].plot(kind='box', ax=axes)
axes.set_ylabel('AWU')
axes.set_xlabel('2')
# Out:
# Text(0.5,0,'2')

# %%
all_data = [data[mask_2]['Actual_AWU'], data[mask_23]['Actual_AWU'], data[mask_231]['Actual_AWU']]
fig = plt.figure(1, figsize=(9, 9))
# Create an axes instance
ax = fig.add_subplot(111)
# Create the boxplot
bp = ax.boxplot(all_data, showfliers=False)
bp = ax.boxplot(all_data, showfliers=False)
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
all_data = [data[mask_15]['Actual_AWU'], data[mask_236]['Actual_AWU'], data[mask_13]['Actual_AWU'], data[mask_33]['Actual_AWU'], data[mask_251]['Actual_AWU']]
fig = plt.figure(1, figsize=(8, 8))
# Create an axes instance
ax = fig.add_subplot(111)
# Create the boxplot

ax.boxplot(all_data, showfliers=False)
x=[1, 2, 3, 4, 5]
y=[0.01455818, 0.0010888, 0.07850374, 0.0733367, 0.00244934]
# median=[0.02880134578602621, 0.004717840765173711, 0.049903041193749998, 0.10777963577551018, 0.005261156926940643]
ax.scatter(x, y, color='black')
# ax.scatter(x, median, color='blue')
ax.plot(x, y, linestyle='--')
ax.set_xticklabels(['92', '93', '94', '95', '96'])

ax.set_ylabel('AWU')
ax.set_xlabel('week')
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# Text(0.5,0,'week')

# %%
mask_251 = data['clustered_label'] == 0.251
print(data[mask_251])
# Out:
#              ReportDate  Customer       Type          ItemShortName  \
# 80777   28/11/2016 3:00   10759.0  OverStock             TPCA8059-H
# 80778   28/11/2016 3:00   10759.0  OverStock              TC7SZ05FU
# 80779   28/11/2016 3:00   10759.0  OverStock            ERTJZER104F
# 80780   06/03/2017 0:09   10759.0  OverStock              TC7SZ05FU
# 80781  01/03/2017 14:02   10759.0  OverStock              TC7SZ05FU
# 80782  01/03/2017 14:02   10759.0  OverStock              ZTS6011BV
# 80783  19/02/2017 23:55   10759.0  OverStock              TC7SZ05FU
# 80784  19/02/2017 23:55   10759.0  OverStock              ZTS6011BV
# 80785  13/02/2017 15:31   10759.0  OverStock              TC7SZ05FU
# 80786  13/02/2017 15:31   10759.0  OverStock              ZTS6011BV
# 80787  03/02/2017 15:13   10759.0  OverStock              TC7SZ05FU
# 80788  23/01/2017 11:10   10759.0  OverStock              TC7SZ05FU
# 80789  15/01/2017 21:54   10759.0  OverStock  19-237/R6GHBHC-C01/2T
# ...

# %%
mask_25 = data['clustered_label'].between(0.25, 0.259)
print(data[mask_25])
# Out:
#              ReportDate  Customer       Type          ItemShortName  \
# 80777   28/11/2016 3:00   10759.0  OverStock             TPCA8059-H
# 80778   28/11/2016 3:00   10759.0  OverStock              TC7SZ05FU
# 80779   28/11/2016 3:00   10759.0  OverStock            ERTJZER104F
# 80780   06/03/2017 0:09   10759.0  OverStock              TC7SZ05FU
# 80781  01/03/2017 14:02   10759.0  OverStock              TC7SZ05FU
# 80782  01/03/2017 14:02   10759.0  OverStock              ZTS6011BV
# 80783  19/02/2017 23:55   10759.0  OverStock              TC7SZ05FU
# 80784  19/02/2017 23:55   10759.0  OverStock              ZTS6011BV
# 80785  13/02/2017 15:31   10759.0  OverStock              TC7SZ05FU
# 80786  13/02/2017 15:31   10759.0  OverStock              ZTS6011BV
# 80787  03/02/2017 15:13   10759.0  OverStock              TC7SZ05FU
# 80788  23/01/2017 11:10   10759.0  OverStock              TC7SZ05FU
# 80789  15/01/2017 21:54   10759.0  OverStock  19-237/R6GHBHC-C01/2T
# ...

# %%
mask_2 = data['clustered_label'].between(0.2, 0.29)
print(data[mask_2])
# Out:
#              ReportDate  Customer       Type       ItemShortName     Brand  \
# 3462    28/11/2016 3:00   10759.0  OverStock           TC7SZ14FU   TOSHIBA
# 3463   04/09/2016 17:40   10759.0  OverStock      MP20073DH-LF-Z       MPS
# 3464   04/09/2016 17:40   10759.0       FCST     RCLAMP3331ZATFT   SEMTECH
# 3465   04/09/2016 17:40   10759.0  OverStock       SMD1812P110TF      PTTC
# 3466   04/09/2016 17:40   10759.0       FCST           TC7SZ05FU   TOSHIBA
# 3467   04/09/2016 17:40   10759.0  OverStock            TCS40DLR   TOSHIBA
# 3468    29/08/2016 0:03   10759.0       FCST     RCLAMP3331ZATFT   SEMTECH
# 3469    29/08/2016 0:03   10759.0  OverStock       SMD1812P110TF      PTTC
# 3470    29/08/2016 0:03   10759.0       FCST           TC7SZ05FU   TOSHIBA
# 3471    29/08/2016 0:03   10759.0  OverStock          TPCA8059-H   TOSHIBA
# 3472    29/08/2016 0:03   10759.0  OverStock           ZTS6011BV   ZILLTEK
# ...

# %%
all_data = [data[mask_2]['Actual_AWU'], data[mask_25]['Actual_AWU'], data[mask_251]['Actual_AWU']]
fig = plt.figure(1, figsize=(9, 9))
# Create an axes instance
ax = fig.add_subplot(111)
# Create the boxplot
# bp = ax.boxplot(all_data, showfliers=False)
bp = ax.boxplot(all_data)
# Set Labels
ax.set_ylabel('AWU')
ax.set_xticklabels(['Cluster 2', 'Cluster 25', 'Cluster 251'])
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# [Text(0,0,'Cluster 2'), Text(0,0,'Cluster 25'), Text(0,0,'Cluster 251')]

# %%
mask_exclude_231 = data['clustered_label'] != 0.231
print(data[mask_2 & mask_exclude_231])
# Out:
#              ReportDate  Customer       Type       ItemShortName     Brand  \
# 3462    28/11/2016 3:00   10759.0  OverStock           TC7SZ14FU   TOSHIBA
# 3463   04/09/2016 17:40   10759.0  OverStock      MP20073DH-LF-Z       MPS
# 3464   04/09/2016 17:40   10759.0       FCST     RCLAMP3331ZATFT   SEMTECH
# 3465   04/09/2016 17:40   10759.0  OverStock       SMD1812P110TF      PTTC
# 3466   04/09/2016 17:40   10759.0       FCST           TC7SZ05FU   TOSHIBA
# 3467   04/09/2016 17:40   10759.0  OverStock            TCS40DLR   TOSHIBA
# 3468    29/08/2016 0:03   10759.0       FCST     RCLAMP3331ZATFT   SEMTECH
# 3469    29/08/2016 0:03   10759.0  OverStock       SMD1812P110TF      PTTC
# 3470    29/08/2016 0:03   10759.0       FCST           TC7SZ05FU   TOSHIBA
# 3471    29/08/2016 0:03   10759.0  OverStock          TPCA8059-H   TOSHIBA
# 3472    29/08/2016 0:03   10759.0  OverStock           ZTS6011BV   ZILLTEK
# ...

# %%
all_data = [data[mask_2]['Actual_AWU'], data[mask_25]['Actual_AWU'], data[mask_251]['Actual_AWU']]
fig = plt.figure(1, figsize=(9, 9))
# Create an axes instance
ax = fig.add_subplot(111)
# Create the boxplot
# bp = ax.boxplot(all_data, showfliers=False)
bp = ax.boxplot(all_data)
# Set Labels
ax.set_ylabel('AWU')
ax.set_xticklabels(['Cluster 2', 'Cluster 25', 'Cluster 251'])
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# [Text(0,0,'Cluster 2'), Text(0,0,'Cluster 25'), Text(0,0,'Cluster 251')]

# %%
mask_212 = data['clustered_label'] == 0.212
data.ix[67557]['clustered_label']
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# 0.23399999999999999

# %%
mask_212 = data['clustered_label'] == 0.212
data.ix[67557]['clustered_label']
# Out:
# 0.23399999999999999

# %%
# Cluster 11-18
mask_11 = data['clustered_label'].between(0.11, 0.119)
mask_12 = data['clustered_label'].between(0.12, 0.129)
mask_13 = data['clustered_label'].between(0.13, 0.139)
mask_14 = data['clustered_label'].between(0.14, 0.149)
mask_15 = data['clustered_label'].between(0.15, 0.159)
mask_16 = data['clustered_label'].between(0.16, 0.169)
mask_17 = data['clustered_label'].between(0.17, 0.179)
mask_18 = data['clustered_label'].between(0.18, 0.189)

# Cluster 1
mask_1 = data['clustered_label'].between(0.1, 0.19)

# %%
# Cluster 211-218
mask_211 = data['clustered_label'].between(0.211, 0.2119)
mask_212 = data['clustered_label'] == 0.212
mask_213 = data['clustered_label'] == 0.213
mask_214 = data['clustered_label'] == 0.214
mask_215 = data['clustered_label'] == 0.215
mask_216 = data['clustered_label'].between(0.216, 0.2169)
mask_217 = data['clustered_label'] == 0.217
mask_218 = data['clustered_label'] == 0.218

# Cluster 221-228
mask_221 = data['clustered_label'] == 0.221
mask_222 = data['clustered_label'] == 0.222
mask_223 = data['clustered_label'] == 0.223
mask_224 = data['clustered_label'].between(0.2239, 0.2249)
mask_225 = data['clustered_label'] == 0.225
mask_226 = data['clustered_label'] == 0.226
mask_227 = data['clustered_label'].between(0.2269, 0.2279)
mask_228 = data['clustered_label'] == 0.228

# Cluster 231-236
mask_231 = data['clustered_label'] == 0.231
mask_232 = data['clustered_label'].between(0.2319, 0.2329)
mask_233 = data['clustered_label'].between(0.2329, 0.2339)
mask_234 = data['clustered_label'].between(0.2339, 0.2349)
mask_235 = data['clustered_label'].between(0.2349, 0.2359)
mask_236 = data['clustered_label'].between(0.2359, 0.2369)

# Cluster 251-256
mask_251 = data['clustered_label'] == 0.251
mask_252 = data['clustered_label'] == 0.252
mask_253 = data['clustered_label'] == 0.253
mask_254 = data['clustered_label'] == 0.254
mask_255 = data['clustered_label'] == 0.255
mask_256 = data['clustered_label'] == 0.256

# Cluster 21-26
mask_21 = data['clustered_label'].between(0.21, 0.219)
mask_22 = data['clustered_label'].between(0.22, 0.229)
mask_23 = data['clustered_label'].between(0.23, 0.239)
mask_24 = data['clustered_label'].between(0.24, 0.249)
mask_25 = data['clustered_label'].between(0.25, 0.259)
mask_26 = data['clustered_label'].between(0.26, 0.269)

# Cluster 2
mask_2 = data['clustered_label'].between(0.2, 0.29)

# %%
# Cluster 31-39
mask_31 = data['clustered_label'].between(0.31, 0.319)
mask_32 = data['clustered_label'].between(0.32, 0.329)
mask_33 = data['clustered_label'].between(0.33, 0.339)
mask_34 = data['clustered_label'].between(0.34, 0.349)
mask_35 = data['clustered_label'].between(0.35, 0.359)
mask_36 = data['clustered_label'].between(0.36, 0.369)
mask_37 = data['clustered_label'].between(0.37, 0.379)
mask_38 = data['clustered_label'].between(0.38, 0.389)
mask_39 = data['clustered_label'].between(0.39, 0.399)

# Cluster 3
mask_3 = data['clustered_label'].between(0.3, 0.39)

# %%
# Cluster 41-46
mask_41 = data['clustered_label'].between(0.41, 0.419)
mask_42 = data['clustered_label'].between(0.42, 0.429)
mask_43 = data['clustered_label'].between(0.43, 0.439)
mask_44 = data['clustered_label'].between(0.44, 0.449)
mask_45 = data['clustered_label'].between(0.45, 0.459)
mask_46 = data['clustered_label'].between(0.46, 0.469)

# Cluster 4
mask_4 = data['clustered_label'].between(0.4, 0.49)

# %%
# Cluster 51-58
mask_51 = data['clustered_label'].between(0.51, 0.519)
mask_52 = data['clustered_label'].between(0.52, 0.529)
mask_53 = data['clustered_label'].between(0.53, 0.539)
mask_54 = data['clustered_label'].between(0.54, 0.549)
mask_55 = data['clustered_label'].between(0.55, 0.559)
mask_56 = data['clustered_label'].between(0.56, 0.569)
mask_57 = data['clustered_label'].between(0.57, 0.579)
mask_58 = data['clustered_label'].between(0.58, 0.589)

# Cluster 5
mask_5 = data['clustered_label'].between(0.5, 0.59)

# %%
# Cluster 61-69
mask_61 = data['clustered_label'].between(0.61, 0.619)
mask_62 = data['clustered_label'].between(0.62, 0.629)
mask_63 = data['clustered_label'].between(0.63, 0.639)
mask_64 = data['clustered_label'].between(0.64, 0.649)
mask_65 = data['clustered_label'].between(0.65, 0.659)
mask_66 = data['clustered_label'].between(0.66, 0.669)
mask_67 = data['clustered_label'].between(0.67, 0.679)
mask_68 = data['clustered_label'].between(0.68, 0.689)
mask_69 = data['clustered_label'].between(0.69, 0.699)

# Cluster 6
mask_6 = data['clustered_label'].between(0.6, 0.69)

# %%
#cluster 1
print('cluster 1', len(data[mask_1]))
print('cluster 11', len(data[mask_11]))
print('cluster 12', len(data[mask_12]))
print('cluster 13', len(data[mask_13]))
print('cluster 14', len(data[mask_14]))
print('cluster 15', len(data[mask_15]))
print('cluster 16', len(data[mask_16]))
print('cluster 17', len(data[mask_17]))
print('cluster 18', len(data[mask_18]))

p11 = len(data[mask_11])/len(data)
p12 = len(data[mask_12])/len(data)
p13 = len(data[mask_13])/len(data)
p14 = len(data[mask_14])/len(data)
p15 = len(data[mask_15])/len(data)
p16 = len(data[mask_16])/len(data)
p17 = len(data[mask_17])/len(data)
p18 = len(data[mask_18])/len(data)
# Out:
# cluster 1 3462
# cluster 11 245
# cluster 12 984
# cluster 13 144
# cluster 14 124
# cluster 15 458
# cluster 16 789
# cluster 17 318
# cluster 18 400

# %%
#cluster 2
print('cluster 2', len(data[mask_2]))
print('cluster 21', len(data[mask_21]))
print('cluster 22', len(data[mask_22]))
print('cluster 23', len(data[mask_23]))
print('cluster 24', len(data[mask_24]))
print('cluster 25', len(data[mask_25]))
print('cluster 26', len(data[mask_26]))

print('cluster 211', len(data[mask_211]))
print('cluster 212', len(data[mask_212]))
print('cluster 213', len(data[mask_213]))
print('cluster 214', len(data[mask_214]))
print('cluster 215', len(data[mask_215]))
print('cluster 216', len(data[mask_216]))
print('cluster 217', len(data[mask_217]))
print('cluster 218', len(data[mask_218]))

print('cluster 221', len(data[mask_221]))
print('cluster 222', len(data[mask_222]))
print('cluster 223', len(data[mask_223]))
print('cluster 224', len(data[mask_224]))
print('cluster 225', len(data[mask_225]))
print('cluster 226', len(data[mask_226]))
print('cluster 227', len(data[mask_227]))
print('cluster 228', len(data[mask_228]))

print('cluster 231', len(data[mask_231]))
print('cluster 232', len(data[mask_232]))
print('cluster 233', len(data[mask_233]))
print('cluster 234', len(data[mask_234]))
print('cluster 235', len(data[mask_235]))
print('cluster 236', len(data[mask_236]))

print('cluster 24', len(data[mask_24]))

print('cluster 251', len(data[mask_251]))
print('cluster 252', len(data[mask_252]))
print('cluster 253', len(data[mask_253]))
print('cluster 254', len(data[mask_254]))
print('cluster 255', len(data[mask_255]))
print('cluster 256', len(data[mask_256]))

p211 = len(data[mask_211])/len(data)
p212 = len(data[mask_212])/len(data)
p213 = len(data[mask_213])/len(data)
p214 = len(data[mask_214])/len(data)
p215 = len(data[mask_215])/len(data)
p216 = len(data[mask_216])/len(data)
p217 = len(data[mask_217])/len(data)
p218 = len(data[mask_218])/len(data)

p221 = len(data[mask_221])/len(data)
p222 = len(data[mask_222])/len(data)
p223 = len(data[mask_223])/len(data)
p224 = len(data[mask_224])/len(data)
p225 = len(data[mask_225])/len(data)
p226 = len(data[mask_226])/len(data)
p227 = len(data[mask_227])/len(data)
p228 = len(data[mask_228])/len(data)

p231 = len(data[mask_231])/len(data)
p232 = len(data[mask_232])/len(data)
p233 = len(data[mask_233])/len(data)
p234 = len(data[mask_234])/len(data)
p235 = len(data[mask_235])/len(data)
p236 = len(data[mask_236])/len(data)

p24 = len(data[mask_24])/len(data)

p251 = len(data[mask_251])/len(data)
p252 = len(data[mask_252])/len(data)
p253 = len(data[mask_253])/len(data)
p254 = len(data[mask_254])/len(data)
p255 = len(data[mask_255])/len(data)
p256 = len(data[mask_256])/len(data)

p26 = len(data[mask_26])/len(data)
# Out:
# cluster 2 80693
# cluster 21 2137
# cluster 22 8626
# cluster 23 65495
# cluster 24 1057
# cluster 25 1681
# cluster 26 1697
# cluster 211 293
# cluster 212 18
# cluster 213 114
# cluster 214 317
# cluster 215 79
# cluster 216 601
# cluster 217 392
# cluster 218 323
# cluster 221 1662
# cluster 222 1523
# cluster 223 505
# cluster 224 972
# cluster 225 290
# cluster 226 8
# cluster 227 2314
# cluster 228 1352
# cluster 231 49441
# cluster 232 1020
# cluster 233 1807
# cluster 234 5282
# cluster 235 5556
# cluster 236 2389
# cluster 24 1057
# cluster 251 219
# cluster 252 194
# cluster 253 119
# cluster 254 321
# cluster 255 641
# cluster 256 187

# %%
#cluster 3
print('cluster 3', len(data[mask_3]))
print('cluster 31', len(data[mask_31]))
print('cluster 32', len(data[mask_32]))
print('cluster 33', len(data[mask_33]))
print('cluster 34', len(data[mask_34]))
print('cluster 35', len(data[mask_35]))
print('cluster 36', len(data[mask_36]))
print('cluster 37', len(data[mask_37]))
print('cluster 38', len(data[mask_38]))
print('cluster 39', len(data[mask_39]))

p31 = len(data[mask_31])/len(data)
p32 = len(data[mask_32])/len(data)
p33 = len(data[mask_33])/len(data)
p34 = len(data[mask_34])/len(data)
p35 = len(data[mask_35])/len(data)
p36 = len(data[mask_36])/len(data)
p37 = len(data[mask_37])/len(data)
p38 = len(data[mask_38])/len(data)
p39 = len(data[mask_39])/len(data)
# Out:
# cluster 3 1000
# cluster 31 30
# cluster 32 340
# cluster 33 98
# cluster 34 52
# cluster 35 46
# cluster 36 194
# cluster 37 69
# cluster 38 107
# cluster 39 64

# %%
#cluster 4
print('cluster 4', len(data[mask_4]))
print('cluster 41', len(data[mask_41]))
print('cluster 42', len(data[mask_42]))
print('cluster 43', len(data[mask_43]))
print('cluster 44', len(data[mask_44]))
print('cluster 45', len(data[mask_45]))
print('cluster 46', len(data[mask_46]))

p41 = len(data[mask_41])/len(data)
p42 = len(data[mask_42])/len(data)
p43 = len(data[mask_43])/len(data)
p44 = len(data[mask_44])/len(data)
p45 = len(data[mask_45])/len(data)
p46 = len(data[mask_46])/len(data)
# Out:
# cluster 4 1598
# cluster 41 141
# cluster 42 168
# cluster 43 212
# cluster 44 557
# cluster 45 148
# cluster 46 372

# %%
#cluster 5
print('cluster 5', len(data[mask_5]))
print('cluster 51', len(data[mask_51]))
print('cluster 52', len(data[mask_52]))
print('cluster 53', len(data[mask_53]))
print('cluster 54', len(data[mask_54]))
print('cluster 55', len(data[mask_55]))
print('cluster 56', len(data[mask_56]))
print('cluster 57', len(data[mask_57]))
print('cluster 58', len(data[mask_58]))

p51 = len(data[mask_51])/len(data)
p52 = len(data[mask_52])/len(data)
p53 = len(data[mask_53])/len(data)
p54 = len(data[mask_54])/len(data)
p55 = len(data[mask_55])/len(data)
p56 = len(data[mask_56])/len(data)
p57 = len(data[mask_57])/len(data)
p58 = len(data[mask_58])/len(data)
# Out:
# cluster 5 338
# cluster 51 16
# cluster 52 16
# cluster 53 39
# cluster 54 20
# cluster 55 76
# cluster 56 56
# cluster 57 72
# cluster 58 43

# %%
#cluster 6
print('cluster 6', len(data[mask_6]))
print('cluster 61', len(data[mask_61]))
print('cluster 62', len(data[mask_62]))
print('cluster 63', len(data[mask_63]))
print('cluster 64', len(data[mask_64]))
print('cluster 65', len(data[mask_65]))
print('cluster 66', len(data[mask_66]))
print('cluster 67', len(data[mask_67]))
print('cluster 68', len(data[mask_68]))
print('cluster 69', len(data[mask_69]))

p61 = len(data[mask_61])/len(data)
p62 = len(data[mask_62])/len(data)
p63 = len(data[mask_63])/len(data)
p64 = len(data[mask_64])/len(data)
p65 = len(data[mask_65])/len(data)
p66 = len(data[mask_66])/len(data)
p67 = len(data[mask_67])/len(data)
p68 = len(data[mask_68])/len(data)
p69 = len(data[mask_69])/len(data)
# Out:
# cluster 6 347
# cluster 61 10
# cluster 62 9
# cluster 63 12
# cluster 64 85
# cluster 65 5
# cluster 66 32
# cluster 67 48
# cluster 68 79
# cluster 69 67

# %%
# Entropy rate
import math
def entropy(lst):
    total = 0
    for a in lst:
        total += a * math.log(a, 2)
    return total * -1

# %%
p_array = []
p_array.append(p11)
p_array.append(p12)
p_array.append(p13)
p_array.append(p14)
p_array.append(p15)
p_array.append(p16)
p_array.append(p17)
p_array.append(p18)

p_array.append(p211)
p_array.append(p212)
p_array.append(p213)
p_array.append(p214)
p_array.append(p215)
p_array.append(p216)
p_array.append(p217)
p_array.append(p218)

p_array.append(p221)
p_array.append(p222)
p_array.append(p223)
p_array.append(p224)
p_array.append(p225)
p_array.append(p226)
p_array.append(p227)
p_array.append(p228)

p_array.append(p231)
p_array.append(p232)
p_array.append(p233)
p_array.append(p234)
p_array.append(p235)
p_array.append(p236)

p_array.append(p24)

p_array.append(p251)
p_array.append(p252)
p_array.append(p253)
p_array.append(p254)
p_array.append(p255)
p_array.append(p256)

p_array.append(p26)

p_array.append(p31)
p_array.append(p32)
p_array.append(p33)
p_array.append(p34)
p_array.append(p35)
p_array.append(p36)
p_array.append(p37)
p_array.append(p38)
p_array.append(p39)

p_array.append(p41)
p_array.append(p42)
p_array.append(p43)
p_array.append(p44)
p_array.append(p45)
p_array.append(p46)

p_array.append(p51)
p_array.append(p52)
p_array.append(p53)
p_array.append(p54)
p_array.append(p55)
p_array.append(p56)
p_array.append(p57)
p_array.append(p58)

p_array.append(p61)
p_array.append(p62)
p_array.append(p63)
p_array.append(p64)
p_array.append(p65)
p_array.append(p66)
p_array.append(p67)
p_array.append(p68)
p_array.append(p69)

p_array
entropy(p_array)
# Out:
# 3.0477124457617744

# %%
#cluster 1
mean_1 = sum(data[mask_1]['Actual_AWU'])/len(data[mask_1]['Actual_AWU'])
var_1 = np.std(data[mask_1]['Actual_AWU'])
print('cluster 1', mean_1, var_1)

mean_11 = sum(data[mask_11]['Actual_AWU'])/len(data[mask_11]['Actual_AWU'])
var_11 = np.std(data[mask_11]['Actual_AWU'])
print('cluster 11', mean_11, var_11)

mean_12 = sum(data[mask_12]['Actual_AWU'])/len(data[mask_12]['Actual_AWU'])
var_12 = np.std(data[mask_12]['Actual_AWU'])
print('cluster 12', mean_12, var_12)

mean_13 = sum(data[mask_13]['Actual_AWU'])/len(data[mask_13]['Actual_AWU'])
var_13 = np.std(data[mask_13]['Actual_AWU'])
print('cluster 13', mean_13, var_13)

mean_14 = sum(data[mask_14]['Actual_AWU'])/len(data[mask_14]['Actual_AWU'])
var_14 = np.std(data[mask_14]['Actual_AWU'])
print('cluster 14', mean_14, var_14)

mean_15 = sum(data[mask_15]['Actual_AWU'])/len(data[mask_15]['Actual_AWU'])
var_15 = np.std(data[mask_15]['Actual_AWU'])
print('cluster 15', mean_15, var_15)

mean_16 = sum(data[mask_16]['Actual_AWU'])/len(data[mask_16]['Actual_AWU'])
var_16 = np.std(data[mask_16]['Actual_AWU'])
print('cluster 16', mean_16, var_16)

mean_17 = sum(data[mask_17]['Actual_AWU'])/len(data[mask_17]['Actual_AWU'])
var_17 = np.std(data[mask_17]['Actual_AWU'])
print('cluster 17', mean_17, var_17)

mean_18 = sum(data[mask_18]['Actual_AWU'])/len(data[mask_18]['Actual_AWU'])
var_18 = np.std(data[mask_18]['Actual_AWU'])
print('cluster 18', mean_18, var_18)
# Out:
# cluster 1 0.0377391491545348 0.02839592505482956
# cluster 11 0.09612700405306121 0.02822884225764698
# cluster 12 0.03397249582317073 0.013503950010807042
# cluster 13 0.05203041193749998 0.02575886844795142
# cluster 14 0.018798281604838717 0.018721244797279525
# cluster 15 0.03080134578602621 0.01476322381166426
# cluster 16 0.016562767984790856 0.013525074868022055
# cluster 17 0.027144361301886816 0.020314466136036245
# cluster 18 0.07010642262000007 0.01928312793049946

# %%
#cluster 2
mean_2 = sum(data[mask_2]['Actual_AWU'])/len(data[mask_2]['Actual_AWU'])
var_2 = np.std(data[mask_2]['Actual_AWU'])
print('cluster 2', mean_2, var_2)

mean_21 = sum(data[mask_21]['Actual_AWU'])/len(data[mask_21]['Actual_AWU'])
var_21 = np.std(data[mask_21]['Actual_AWU'])
print('cluster 21', mean_21, var_21)

mean_22 = sum(data[mask_22]['Actual_AWU'])/len(data[mask_22]['Actual_AWU'])
var_22 = np.std(data[mask_22]['Actual_AWU'])
print('cluster 22', mean_22, var_22)

mean_23 = sum(data[mask_23]['Actual_AWU'])/len(data[mask_23]['Actual_AWU'])
var_23 = np.std(data[mask_23]['Actual_AWU'])
print('cluster 23', mean_23, var_23)

mean_24 = sum(data[mask_24]['Actual_AWU'])/len(data[mask_24]['Actual_AWU'])
var_24 = np.std(data[mask_24]['Actual_AWU'])
print('cluster 24', mean_24, var_24)

mean_25 = sum(data[mask_25]['Actual_AWU'])/len(data[mask_25]['Actual_AWU'])
var_25 = np.std(data[mask_25]['Actual_AWU'])
print('cluster 25', mean_25, var_25)

mean_26 = sum(data[mask_26]['Actual_AWU'])/len(data[mask_26]['Actual_AWU'])
var_26 = np.std(data[mask_26]['Actual_AWU'])
print('cluster 26', mean_26, var_26)

len(data[mask_211]['Actual_AWU'])

mean_211 = sum(data[mask_211]['Actual_AWU'])/len(data[mask_211]['Actual_AWU'])
var_211 = np.std(data[mask_211]['Actual_AWU'])
print('cluster 211', mean_211, var_211)

mean_212 = sum(data[mask_212]['Actual_AWU'])/len(data[mask_212]['Actual_AWU'])
var_212 = np.std(data[mask_212]['Actual_AWU'])
print('cluster 212', mean_212, var_212)

mean_213 = sum(data[mask_213]['Actual_AWU'])/len(data[mask_213]['Actual_AWU'])
var_213 = np.std(data[mask_213]['Actual_AWU'])
print('cluster 213', mean_213, var_213)

mean_214 = sum(data[mask_214]['Actual_AWU'])/len(data[mask_214]['Actual_AWU'])
var_214 = np.std(data[mask_214]['Actual_AWU'])
print('cluster 214', mean_214, var_214)

mean_215 = sum(data[mask_215]['Actual_AWU'])/len(data[mask_215]['Actual_AWU'])
var_215 = np.std(data[mask_215]['Actual_AWU'])
print('cluster 215', mean_215, var_215)

mean_216 = sum(data[mask_216]['Actual_AWU'])/len(data[mask_216]['Actual_AWU'])
var_216 = np.std(data[mask_216]['Actual_AWU'])
print('cluster 216', mean_216, var_216)

mean_217 = sum(data[mask_217]['Actual_AWU'])/len(data[mask_217]['Actual_AWU'])
var_217 = np.std(data[mask_217]['Actual_AWU'])
print('cluster 217', mean_217, var_217)

mean_218 = sum(data[mask_218]['Actual_AWU'])/len(data[mask_218]['Actual_AWU'])
var_218 = np.std(data[mask_218]['Actual_AWU'])
print('cluster 218', mean_218, var_218)

mean_221 = sum(data[mask_221]['Actual_AWU'])/len(data[mask_221]['Actual_AWU'])
var_221 = np.std(data[mask_221]['Actual_AWU'])
print('cluster 221', mean_221, var_221)

mean_222 = sum(data[mask_222]['Actual_AWU'])/len(data[mask_222]['Actual_AWU'])
var_222 = np.std(data[mask_222]['Actual_AWU'])
print('cluster 222', mean_222, var_222)

mean_223 = sum(data[mask_223]['Actual_AWU'])/len(data[mask_223]['Actual_AWU'])
var_223 = np.std(data[mask_223]['Actual_AWU'])
print('cluster 223', mean_223, var_223)

mean_224 = sum(data[mask_224]['Actual_AWU'])/len(data[mask_224]['Actual_AWU'])
var_224 = np.std(data[mask_224]['Actual_AWU'])
print('cluster 224', mean_224, var_224)

mean_225 = sum(data[mask_225]['Actual_AWU'])/len(data[mask_225]['Actual_AWU'])
var_225 = np.std(data[mask_225]['Actual_AWU'])
print('cluster 225', mean_225, var_225)

mean_226 = sum(data[mask_226]['Actual_AWU'])/len(data[mask_226]['Actual_AWU'])
var_226 = np.std(data[mask_226]['Actual_AWU'])
print('cluster 226', mean_226, var_226)

mean_227 = sum(data[mask_227]['Actual_AWU'])/len(data[mask_227]['Actual_AWU'])
var_227 = np.std(data[mask_227]['Actual_AWU'])
print('cluster 227', mean_227, var_227)

mean_228 = sum(data[mask_228]['Actual_AWU'])/len(data[mask_228]['Actual_AWU'])
var_228 = np.std(data[mask_228]['Actual_AWU'])
print('cluster 228', mean_228, var_228)

mean_231 = sum(data[mask_231]['Actual_AWU'])/len(data[mask_231]['Actual_AWU'])
var_231 = np.std(data[mask_231]['Actual_AWU'])
print('cluster 231', mean_231, var_231)

mean_232 = sum(data[mask_232]['Actual_AWU'])/len(data[mask_232]['Actual_AWU'])
var_232 = np.std(data[mask_232]['Actual_AWU'])
print('cluster 232', mean_232, var_232)

mean_233 = sum(data[mask_233]['Actual_AWU'])/len(data[mask_233]['Actual_AWU'])
var_233 = np.std(data[mask_233]['Actual_AWU'])
print('cluster 233', mean_233, var_233)

mean_234 = sum(data[mask_234]['Actual_AWU'])/len(data[mask_234]['Actual_AWU'])
var_234 = np.std(data[mask_234]['Actual_AWU'])
print('cluster 234', mean_234, var_234)

mean_235 = sum(data[mask_235]['Actual_AWU'])/len(data[mask_235]['Actual_AWU'])
var_235 = np.std(data[mask_235]['Actual_AWU'])
print('cluster 235', mean_235, var_235)

mean_236 = sum(data[mask_236]['Actual_AWU'])/len(data[mask_236]['Actual_AWU'])
var_236 = np.std(data[mask_236]['Actual_AWU'])
print('cluster 236', mean_236, var_236)

mean_251 = sum(data[mask_251]['Actual_AWU'])/len(data[mask_251]['Actual_AWU'])
var_251 = np.std(data[mask_251]['Actual_AWU'])
print('cluster 251', mean_251, var_251)

mean_252 = sum(data[mask_252]['Actual_AWU'])/len(data[mask_252]['Actual_AWU'])
var_252 = np.std(data[mask_252]['Actual_AWU'])
print('cluster 252', mean_252, var_252)

mean_253 = sum(data[mask_253]['Actual_AWU'])/len(data[mask_253]['Actual_AWU'])
var_253 = np.std(data[mask_253]['Actual_AWU'])
print('cluster 253', mean_253, var_253)

mean_254 = sum(data[mask_254]['Actual_AWU'])/len(data[mask_254]['Actual_AWU'])
var_254 = np.std(data[mask_254]['Actual_AWU'])
print('cluster 254', mean_254, var_254)

mean_255 = sum(data[mask_255]['Actual_AWU'])/len(data[mask_255]['Actual_AWU'])
var_255 = np.std(data[mask_255]['Actual_AWU'])
print('cluster 255', mean_255, var_255)

mean_256 = sum(data[mask_256]['Actual_AWU'])/len(data[mask_256]['Actual_AWU'])
var_256 = np.std(data[mask_256]['Actual_AWU'])
print('cluster 256', mean_256, var_256)
# Out:
# cluster 2 0.002091916304213788 0.0052229628210779195
# cluster 21 0.011277332715021017 0.008242503967686386
# cluster 22 0.004780902800370915 0.0035447379276789676
# cluster 23 0.0005177261139323454 0.0011112460034763685
# cluster 24 0.013676163192052984 0.008810891202844992
# cluster 25 0.007581467876859008 0.007399389279255957
# cluster 26 0.024958545044784865 0.011068428313448423
# cluster 211 0.004272737634812285 0.0043401516553505945
# cluster 212 0.002487134444444444 0.0018194828965043038
# cluster 213 0.005706199956140348 0.004391050161571671
# cluster 214 0.0025575086466876904 0.003340353614650037
# cluster 215 0.020477310569620256 0.004949902108424553
# cluster 216 0.009542349242928445 0.004566445846459363
# cluster 217 0.02094921170918368 0.0049969813086636165
# cluster 218 0.01788542417647059 0.004634436613626143
# cluster 221 0.009006075552346572 0.0022910821073778
# cluster 222 0.0031506294005252673 0.002546244851742797
# ...

# %%
#cluster 3
mean_3 = sum(data[mask_3]['Actual_AWU'])/len(data[mask_3]['Actual_AWU'])
var_3 = np.std(data[mask_3]['Actual_AWU'])
print('cluster 3', mean_3, var_3)

mean_31 = sum(data[mask_31]['Actual_AWU'])/len(data[mask_31]['Actual_AWU'])
var_31 = np.std(data[mask_31]['Actual_AWU'])
print('cluster 31', mean_31, var_31)

mean_32 = sum(data[mask_32]['Actual_AWU'])/len(data[mask_32]['Actual_AWU'])
var_32 = np.std(data[mask_32]['Actual_AWU'])
print('cluster 32', mean_32, var_32)

mean_33 = sum(data[mask_33]['Actual_AWU'])/len(data[mask_33]['Actual_AWU'])
var_33 = np.std(data[mask_33]['Actual_AWU'])
print('cluster 33', mean_33, var_33)

mean_34 = sum(data[mask_34]['Actual_AWU'])/len(data[mask_34]['Actual_AWU'])
var_34 = np.std(data[mask_34]['Actual_AWU'])
print('cluster 34', mean_34, var_34)

mean_35 = sum(data[mask_35]['Actual_AWU'])/len(data[mask_35]['Actual_AWU'])
var_35 = np.std(data[mask_35]['Actual_AWU'])
print('cluster 35', mean_35, var_35)

mean_36 = sum(data[mask_36]['Actual_AWU'])/len(data[mask_36]['Actual_AWU'])
var_36 = np.std(data[mask_36]['Actual_AWU'])
print('cluster 36', mean_36, var_36)

mean_37 = sum(data[mask_37]['Actual_AWU'])/len(data[mask_37]['Actual_AWU'])
var_37 = np.std(data[mask_37]['Actual_AWU'])
print('cluster 37', mean_37, var_37)

mean_38 = sum(data[mask_38]['Actual_AWU'])/len(data[mask_38]['Actual_AWU'])
var_38 = np.std(data[mask_38]['Actual_AWU'])
print('cluster 38', mean_38, var_38)

mean_39 = sum(data[mask_39]['Actual_AWU'])/len(data[mask_39]['Actual_AWU'])
var_39 = np.std(data[mask_39]['Actual_AWU'])
print('cluster 39', mean_39, var_39)
# Out:
# cluster 3 0.16351304436300015 0.11832237711310739
# cluster 31 0.20976445893333337 0.1045874227460119
# cluster 32 0.07779373033823528 0.038303836663026045
# cluster 33 0.11877963577551018 0.047354972883910704
# cluster 34 0.038073825538461545 0.03842395303485038
# cluster 35 0.1600033492608695 0.055104506762810306
# cluster 36 0.18049495195876272 0.04735244693468685
# cluster 37 0.2984476619420288 0.08072882140528397
# cluster 38 0.24879464391588788 0.07084867822197423
# cluster 39 0.4306235738593749 0.12997268099065817

# %%
#cluster 4
mean_4 = sum(data[mask_4]['Actual_AWU'])/len(data[mask_4]['Actual_AWU'])
var_4 = np.std(data[mask_4]['Actual_AWU'])
print('cluster 4', mean_4, var_4)

mean_41 = sum(data[mask_41]['Actual_AWU'])/len(data[mask_41]['Actual_AWU'])
var_41 = np.std(data[mask_41]['Actual_AWU'])
print('cluster 41', mean_41, var_41)

mean_42 = sum(data[mask_42]['Actual_AWU'])/len(data[mask_42]['Actual_AWU'])
var_42 = np.std(data[mask_42]['Actual_AWU'])
print('cluster 42', mean_42, var_42)

mean_43 = sum(data[mask_43]['Actual_AWU'])/len(data[mask_43]['Actual_AWU'])
var_43 = np.std(data[mask_43]['Actual_AWU'])
print('cluster 43', mean_43, var_43)

mean_44 = sum(data[mask_44]['Actual_AWU'])/len(data[mask_44]['Actual_AWU'])
var_44 = np.std(data[mask_44]['Actual_AWU'])
print('cluster 44', mean_44, var_44)

mean_45 = sum(data[mask_45]['Actual_AWU'])/len(data[mask_45]['Actual_AWU'])
var_45 = np.std(data[mask_45]['Actual_AWU'])
print('cluster 45', mean_45, var_45)

mean_46 = sum(data[mask_46]['Actual_AWU'])/len(data[mask_46]['Actual_AWU'])
var_46 = np.std(data[mask_46]['Actual_AWU'])
print('cluster 46', mean_46, var_46)
# Out:
# cluster 4 0.03845144833729667 0.029503245073353997
# cluster 41 0.040101022106382986 0.022856032494305817
# cluster 42 0.06948662200000003 0.03566437036631626
# cluster 43 0.038752912797169844 0.02146489659224417
# cluster 44 0.02201802481867146 0.01742165348908782
# cluster 45 0.07823470591216208 0.031224864677124205
# cluster 46 0.0324167312311828 0.018848513588882686

# %%
#cluster 5
mean_5 = sum(data[mask_5]['Actual_AWU'])/len(data[mask_5]['Actual_AWU'])
var_5 = np.std(data[mask_5]['Actual_AWU'])
print('cluster 5', mean_5, var_5)

mean_51 = sum(data[mask_51]['Actual_AWU'])/len(data[mask_51]['Actual_AWU'])
var_51 = np.std(data[mask_51]['Actual_AWU'])
print('cluster 51', mean_51, var_51)

mean_52 = sum(data[mask_52]['Actual_AWU'])/len(data[mask_52]['Actual_AWU'])
var_52 = np.std(data[mask_52]['Actual_AWU'])
print('cluster 52', mean_52, var_52)

mean_53 = sum(data[mask_53]['Actual_AWU'])/len(data[mask_53]['Actual_AWU'])
var_53 = np.std(data[mask_53]['Actual_AWU'])
print('cluster 53', mean_53, var_53)

mean_54 = sum(data[mask_54]['Actual_AWU'])/len(data[mask_54]['Actual_AWU'])
var_54 = np.std(data[mask_54]['Actual_AWU'])
print('cluster 54', mean_54, var_54)

mean_55 = sum(data[mask_55]['Actual_AWU'])/len(data[mask_55]['Actual_AWU'])
var_55 = np.std(data[mask_55]['Actual_AWU'])
print('cluster 55', mean_55, var_55)

mean_56 = sum(data[mask_56]['Actual_AWU'])/len(data[mask_56]['Actual_AWU'])
var_56 = np.std(data[mask_56]['Actual_AWU'])
print('cluster 56', mean_56, var_56)

mean_57 = sum(data[mask_57]['Actual_AWU'])/len(data[mask_57]['Actual_AWU'])
var_57 = np.std(data[mask_57]['Actual_AWU'])
print('cluster 57', mean_57, var_57)

mean_58 = sum(data[mask_58]['Actual_AWU'])/len(data[mask_58]['Actual_AWU'])
var_58 = np.std(data[mask_58]['Actual_AWU'])
print('cluster 58', mean_58, var_58)
# Out:
# cluster 5 0.36075613849704097 0.17758956689640068
# cluster 51 0.260397093625 0.06976205459672637
# cluster 52 0.300348893375 0.07554637220546159
# cluster 53 0.33250213182051286 0.09420642577020479
# cluster 54 0.43321562515000006 0.21226217986661675
# cluster 55 0.2762765533552632 0.09706411937176687
# cluster 56 0.3050445800178571 0.12338948469934712
# cluster 57 0.5973577928472222 0.1363619274163131
# cluster 58 0.23819692453488372 0.11690338132419514

# %%
#cluster 6
mean_6 = sum(data[mask_6]['Actual_AWU'])/len(data[mask_6]['Actual_AWU'])
var_6 = np.std(data[mask_6]['Actual_AWU'])
print('cluster 6', mean_6, var_6)

mean_61 = sum(data[mask_61]['Actual_AWU'])/len(data[mask_61]['Actual_AWU'])
var_61 = np.std(data[mask_61]['Actual_AWU'])
print('cluster 61', mean_61, var_61)

mean_62 = sum(data[mask_62]['Actual_AWU'])/len(data[mask_62]['Actual_AWU'])
var_62 = np.std(data[mask_62]['Actual_AWU'])
print('cluster 62', mean_62, var_62)

mean_63 = sum(data[mask_63]['Actual_AWU'])/len(data[mask_63]['Actual_AWU'])
var_63 = np.std(data[mask_63]['Actual_AWU'])
print('cluster 63', mean_63, var_63)

mean_64 = sum(data[mask_64]['Actual_AWU'])/len(data[mask_64]['Actual_AWU'])
var_64 = np.std(data[mask_64]['Actual_AWU'])
print('cluster 64', mean_64, var_64)

mean_65 = sum(data[mask_65]['Actual_AWU'])/len(data[mask_65]['Actual_AWU'])
var_65 = np.std(data[mask_65]['Actual_AWU'])
print('cluster 65', mean_65, var_65)

mean_66 = sum(data[mask_66]['Actual_AWU'])/len(data[mask_66]['Actual_AWU'])
var_66 = np.std(data[mask_66]['Actual_AWU'])
print('cluster 66', mean_66, var_66)

mean_67 = sum(data[mask_67]['Actual_AWU'])/len(data[mask_67]['Actual_AWU'])
var_67 = np.std(data[mask_67]['Actual_AWU'])
print('cluster 67', mean_67, var_67)

mean_68 = sum(data[mask_68]['Actual_AWU'])/len(data[mask_68]['Actual_AWU'])
var_68 = np.std(data[mask_68]['Actual_AWU'])
print('cluster 68', mean_68, var_68)

mean_69 = sum(data[mask_69]['Actual_AWU'])/len(data[mask_69]['Actual_AWU'])
var_69 = np.std(data[mask_69]['Actual_AWU'])
print('cluster 69', mean_69, var_69)
# Out:
# cluster 6 0.1304746427636888 0.09394155978235004
# cluster 61 0.0288438898 0.0351998719614626
# cluster 62 0.17451277111111113 0.03160050429513162
# cluster 63 0.2654424434166667 0.07343418431607292
# cluster 64 0.09286812374117646 0.05163639555839709
# cluster 65 0.5499774876 0.0890995833337444
# cluster 66 0.20098810159374997 0.08158915385945875
# cluster 67 0.15910298841666665 0.04948719538070771
# cluster 68 0.06231498755696204 0.0357881630860705
# cluster 69 0.1581375106268656 0.06931598672204921

# %%
data['clustered_label']
len(data[mask_211]['Actual_AWU'])
# Out:
# 0

# %%
# print('(',round(mean_211, 5),',',round(var_211, 5),')')
c211 = '('+str(round(mean_211, 5))+', '+str(round(var_211, 5))+')'
c212 = '('+str(round(mean_212, 5))+', '+str(round(var_212, 5))+')'
c213 = '('+str(round(mean_213, 5))+', '+str(round(var_213, 5))+')'
c214 = '('+str(round(mean_214, 5))+', '+str(round(var_214, 5))+')'
c215 = '('+str(round(mean_215, 5))+', '+str(round(var_215, 5))+')'
c216 = '('+str(round(mean_216, 5))+', '+str(round(var_216, 5))+')'
c21 = '('+str(round(mean_21, 5))+', '+str(round(var_21, 5))+')'
print(c211)
print(c212)
print(c213)
print(c214)
print(c215)
print(c216)
print(c21)
# Out:
# (0.00427, 0.00434)
# (0.00249, 0.00182)
# (0.00571, 0.00439)
# (0.00256, 0.00334)
# (0.02048, 0.00495)
# (0.00954, 0.00457)
# (0.01128, 0.00824)

# %%
c221 = '('+str(round(mean_221, 5))+', '+str(round(var_221, 5))+')'
c222 = '('+str(round(mean_222, 5))+', '+str(round(var_222, 5))+')'
c223 = '('+str(round(mean_223, 5))+', '+str(round(var_223, 5))+')'
c224 = '('+str(round(mean_224, 5))+', '+str(round(var_224, 5))+')'
c225 = '('+str(round(mean_225, 5))+', '+str(round(var_225, 5))+')'
c226 = '('+str(round(mean_226, 5))+', '+str(round(var_226, 5))+')'
c22 = '('+str(round(mean_22, 5))+', '+str(round(var_22, 5))+')'
c2 = '('+str(round(mean_2, 5))+', '+str(round(var_2, 5))+')'
print(c221)
print(c222)
print(c223)
print(c224)
print(c225)
print(c226)
print(c22)
print(c2)
# Out:
# (0.00901, 0.00229)
# (0.00315, 0.00255)
# (0.00598, 0.00369)
# (0.00568, 0.00305)
# (0.00376, 0.0034)
# (0.00338, 0.00457)
# (0.00478, 0.00354)
# (0.00209, 0.00522)

# %%
c231 = '('+str(round(mean_231, 5))+', '+str(round(var_231, 5))+')'
c232 = '('+str(round(mean_232, 5))+', '+str(round(var_232, 5))+')'
c233 = '('+str(round(mean_233, 5))+', '+str(round(var_233, 5))+')'
c234 = '('+str(round(mean_234, 5))+', '+str(round(var_234, 5))+')'
c235 = '('+str(round(mean_235, 5))+', '+str(round(var_235, 5))+')'
c236 = '('+str(round(mean_236, 5))+', '+str(round(var_236, 5))+')'
c23 = '('+str(round(mean_23, 5))+', '+str(round(var_23, 5))+')'
print(c231)
print(c232)
print(c233)
print(c234)
print(c235)
print(c236)
print(c23)
# Out:
# (0.00019, 0.00039)
# (0.00185, 0.00129)
# (0.00101, 0.00114)
# (0.00069, 0.00075)
# (0.00111, 0.00102)
# (0.00472, 0.0019)
# (0.00052, 0.00111)

# %%
c251 = '('+str(round(mean_251, 5))+', '+str(round(var_251, 5))+')'
c252 = '('+str(round(mean_252, 5))+', '+str(round(var_252, 5))+')'
c253 = '('+str(round(mean_253, 5))+', '+str(round(var_253, 5))+')'
c254 = '('+str(round(mean_254, 5))+', '+str(round(var_254, 5))+')'
c255 = '('+str(round(mean_255, 5))+', '+str(round(var_255, 5))+')'
c256 = '('+str(round(mean_256, 5))+', '+str(round(var_256, 5))+')'
c24 = '('+str(round(mean_24, 5))+', '+str(round(var_24, 5))+')'
c25 = '('+str(round(mean_25, 5))+', '+str(round(var_25, 5))+')'
c26 = '('+str(round(mean_26, 5))+', '+str(round(var_26, 5))+')'
print(c251)
print(c252)
print(c253)
print(c254)
print(c255)
print(c256)
print(c24)
print(c25)
print(c26)
# Out:
# (0.00536, 0.00426)
# (0.00849, 0.00459)
# (0.02612, 0.00731)
# (0.00457, 0.00392)
# (0.00544, 0.00491)
# (0.00994, 0.00662)
# (0.01368, 0.00881)
# (0.00758, 0.0074)
# (0.02496, 0.01107)

# %%
c11 = '('+str(round(mean_11, 5))+', '+str(round(var_11, 5))+')'
c12 = '('+str(round(mean_12, 5))+', '+str(round(var_12, 5))+')'
c13 = '('+str(round(mean_13, 5))+', '+str(round(var_13, 5))+')'
c14 = '('+str(round(mean_14, 5))+', '+str(round(var_14, 5))+')'
c15 = '('+str(round(mean_15, 5))+', '+str(round(var_15, 5))+')'
c16 = '('+str(round(mean_16, 5))+', '+str(round(var_16, 5))+')'
c17 = '('+str(round(mean_17, 5))+', '+str(round(var_17, 5))+')'
c18 = '('+str(round(mean_18, 5))+', '+str(round(var_18, 5))+')'
c1 = '('+str(round(mean_1, 5))+', '+str(round(var_1, 5))+')'
print(c11)
print(c12)
print(c13)
print(c14)
print(c15)
print(c16)
print(c17)
print(c18)
print(c1)
# Out:
# (0.09613, 0.02823)
# (0.03397, 0.0135)
# (0.05203, 0.02576)
# (0.0188, 0.01872)
# (0.0308, 0.01476)
# (0.01656, 0.01353)
# (0.02714, 0.02031)
# (0.07011, 0.01928)
# (0.03774, 0.0284)

# %%
c31 = '('+str(round(mean_31, 5))+', '+str(round(var_31, 5))+')'
c32 = '('+str(round(mean_32, 5))+', '+str(round(var_32, 5))+')'
c33 = '('+str(round(mean_33, 5))+', '+str(round(var_33, 5))+')'
c34 = '('+str(round(mean_34, 5))+', '+str(round(var_34, 5))+')'
c35 = '('+str(round(mean_35, 5))+', '+str(round(var_35, 5))+')'
c36 = '('+str(round(mean_36, 5))+', '+str(round(var_36, 5))+')'
c37 = '('+str(round(mean_37, 5))+', '+str(round(var_37, 5))+')'
c38 = '('+str(round(mean_38, 5))+', '+str(round(var_38, 5))+')'
c39 = '('+str(round(mean_39, 5))+', '+str(round(var_39, 5))+')'
c3 = '('+str(round(mean_3, 5))+', '+str(round(var_3, 5))+')'
print(c31)
print(c32)
print(c33)
print(c34)
print(c35)
print(c36)
print(c37)
print(c38)
print(c39)
print(c3)
# Out:
# (0.20976, 0.10459)
# (0.07779, 0.0383)
# (0.11878, 0.04735)
# (0.03807, 0.03842)
# (0.16, 0.0551)
# (0.18049, 0.04735)
# (0.29845, 0.08073)
# (0.24879, 0.07085)
# (0.43062, 0.12997)
# (0.16351, 0.11832)

# %%
c41 = '('+str(round(mean_41, 5))+', '+str(round(var_41, 5))+')'
c42 = '('+str(round(mean_42, 5))+', '+str(round(var_42, 5))+')'
c43 = '('+str(round(mean_43, 5))+', '+str(round(var_43, 5))+')'
c44 = '('+str(round(mean_44, 5))+', '+str(round(var_44, 5))+')'
c45 = '('+str(round(mean_45, 5))+', '+str(round(var_45, 5))+')'
c46 = '('+str(round(mean_46, 5))+', '+str(round(var_46, 5))+')'
c4 = '('+str(round(mean_4, 5))+', '+str(round(var_4, 5))+')'

print(c41)
print(c42)
print(c43)
print(c44)
print(c45)
print(c46)
print(c4)
# Out:
# (0.0401, 0.02286)
# (0.06949, 0.03566)
# (0.03875, 0.02146)
# (0.02202, 0.01742)
# (0.07823, 0.03122)
# (0.03242, 0.01885)
# (0.03845, 0.0295)

# %%
c51 = '('+str(round(mean_51, 5))+', '+str(round(var_51, 5))+')'
c52 = '('+str(round(mean_52, 5))+', '+str(round(var_52, 5))+')'
c53 = '('+str(round(mean_53, 5))+', '+str(round(var_53, 5))+')'
c54 = '('+str(round(mean_54, 5))+', '+str(round(var_54, 5))+')'
c55 = '('+str(round(mean_55, 5))+', '+str(round(var_55, 5))+')'
c56 = '('+str(round(mean_56, 5))+', '+str(round(var_56, 5))+')'
c57 = '('+str(round(mean_57, 5))+', '+str(round(var_57, 5))+')'
c58 = '('+str(round(mean_58, 5))+', '+str(round(var_58, 5))+')'
c5 = '('+str(round(mean_5, 5))+', '+str(round(var_5, 5))+')'
print(c51)
print(c52)
print(c53)
print(c54)
print(c55)
print(c56)
print(c57)
print(c58)
print(c5)
# Out:
# (0.2604, 0.06976)
# (0.30035, 0.07555)
# (0.3325, 0.09421)
# (0.43322, 0.21226)
# (0.27628, 0.09706)
# (0.30504, 0.12339)
# (0.59736, 0.13636)
# (0.2382, 0.1169)
# (0.36076, 0.17759)

# %%
c61 = '('+str(round(mean_61, 5))+', '+str(round(var_61, 5))+')'
c62 = '('+str(round(mean_62, 5))+', '+str(round(var_62, 5))+')'
c63 = '('+str(round(mean_63, 5))+', '+str(round(var_63, 5))+')'
c64 = '('+str(round(mean_64, 5))+', '+str(round(var_64, 5))+')'
c65 = '('+str(round(mean_65, 5))+', '+str(round(var_65, 5))+')'
c66 = '('+str(round(mean_66, 5))+', '+str(round(var_66, 5))+')'
c67 = '('+str(round(mean_67, 5))+', '+str(round(var_67, 5))+')'
c68 = '('+str(round(mean_68, 5))+', '+str(round(var_68, 5))+')'
c69 = '('+str(round(mean_69, 5))+', '+str(round(var_69, 5))+')'
c6 = '('+str(round(mean_6, 5))+', '+str(round(var_6, 5))+')'
print(c61)
print(c62)
print(c63)
print(c64)
print(c65)
print(c66)
print(c67)
print(c68)
print(c69)
print(c6)
# Out:
# (0.02884, 0.0352)
# (0.17451, 0.0316)
# (0.26544, 0.07343)
# (0.09287, 0.05164)
# (0.54998, 0.0891)
# (0.20099, 0.08159)
# (0.1591, 0.04949)
# (0.06231, 0.03579)
# (0.15814, 0.06932)
# (0.13047, 0.09394)

# %%
print(data)
# Out:
#              ReportDate  Customer       Type          ItemShortName  \
# 0       28/11/2016 3:00   10759.0     Normal              EVPAKB01A
# 1       28/11/2016 3:00   10759.0     Normal              TC7SZ07FU
# 2      04/09/2016 17:40   10759.0     Normal           DF2B6.8M1ACT
# 3      04/09/2016 17:40   10759.0     Normal     PD12-206B/L512/TR8
# 4      04/09/2016 17:40   10759.0     Normal              EVPAKB01A
# 5       29/08/2016 0:03   10759.0     Normal  19-237/R6GHBHC-C01/2T
# 6       29/08/2016 0:03   10759.0     Normal     PD12-206B/L512/TR8
# 7      19/08/2016 17:25   10759.0     Normal  19-237/R6GHBHC-C01/2T
# 8      19/08/2016 17:25   10759.0     Normal             DSF01S30SC
# 9      12/08/2016 18:06   10759.0     Normal  19-237/R6GHBHC-C01/2T
# 10     12/08/2016 18:06   10759.0     Normal             DSF01S30SC
# 11     20/11/2016 22:28   10759.0     Normal              EVPAKB01A
# 12     20/11/2016 22:28   10759.0     Normal     IR12-206C/L268/TR8
# ...
