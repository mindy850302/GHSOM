# 119         119  101205093   6461   6464   6464   6240   6450   6450   6461
# 120         120  101205043   6463   6464   6461   6463   6461   6350   6461
# 121         121  101205029   6461   6450   6559   6461   6465   3640   6463
# 122         122  101204026   6461   6450   6465   3650   6450   6461   6461
# 123         123  101203054   6461   6464   6461   6600   6461   6465   6461
# 124         124  101203004   6461   6461   6461   6464   6463   6463   6461
# 125         125  101103034   6461   6464   6461   6464   6461   6463   6461
# 126         126  101102026   6461   6461   6463   6463   6463   6220   6461
# 127         127  101102025   6461   6461   6463   6450   6210   3620   6463
# 128         128  101101050   6461   6463   6465   6461   6461   6461   6465
# 129         129  100508018   6461   6464   6100   6409   3620   6463   6463
# 130         130  100401072   6461   6461   6463   6420   6450   6310   6465
# 131         131  100401044   6461   6461   6420   6461   6461   6530   6420
# 132         132  100208053   6461   6409   6461   6463   6461   6440   6461
# 133         133  100206009   6461   6461   6440   6461   6440   6530   6461
# 134         134  100202044   6461   6461   6465   6210   6463   6461   6463
# 135         135  100104041   6461   6463   6464   6461   6463   6461   6450
# 136         136  100101021   6461   6465   6420   6465   6420   6450   6464
#
#      week8    ...     week14  week15  week16  week17  week18  clustered_label  \
# 0     6461    ...       6461    6461    6461    6461    6461               35
# 1     6461    ...       6461    6461    6461    6461    6450               43
# 2     6461    ...       6463    6461    6463    3300    6461               20
# 3     6461    ...       6420    6464    6461    6461    6461               42
# 4     6461    ...       6461    6461    6461    6461    5100               20
# 5     6461    ...       6461    6461    6461    6420    6520               34
# 6     6464    ...       6463    6559    6461    6461    3640               20
# 7     6461    ...       6461    6461    6461    6461    6461               31
# 8     4500    ...       6461    6461    6464    3650    6409               43
# 9     6462    ...       6461    6461    6461    6461    5500               35
# 10    6465    ...       6461    6461    6463    6461    6409               20
# 11    6461    ...       6461    6461    6461    6461    5400               10
# 12    6310    ...       6461    6461    6461    6461    6462               35
# 13    6461    ...       6461    6461    6461    6461    6461               34
# 14    6461    ...       6461    6461    6461    6465    6465               41
# 15    6461    ...       6463    6463    6461    6463    6240               34
# 16    6461    ...       6463    6464    6461    6463    6430               10
# 17    6461    ...       6461    6559    6461    6461    6461               42
# 18    6463    ...       6461    6461    6461    6461    1400               42
# 19    6461    ...       6240    6461    6461    6220    3620               42
# 20    6450    ...       6450    6240    6461    6464    5100               20
# 21    6420    ...       6461    6461    6461    1400    6509               10
# 22    6463    ...       6465    6464    6461    6461    6600               35
# 23    3620    ...       6463    6420    6463    6461    3640               20
# 24    6461    ...       6461    3300    6461    6461    6461               20
# 25    6450    ...       6450    6450    6461    6461    6210               44
# 26    6461    ...       6461    6461    6461    6461    6461               20
# 27    6461    ...       6461    6461    3640    6461    3500               34
# 28    6461    ...       6420    6461    6461    6463    6600               33
# 29    6463    ...       6461    6461    6461    6461    6430               44
# ..     ...    ...        ...     ...     ...     ...     ...              ...
# 107   6461    ...       6461    6461    6461    6463    6462               41
# 108   6461    ...       6464    6463    6461    6461    6463               44
# 109   6465    ...       6463    6461    6461    6461    6461               34
# 110   6461    ...       6461    6461    6461    6461    3620               10
# 111   6461    ...       6420    6461    6461    6461    6559               35
# 112   6461    ...       6461    6461    6461    6463    6540               20
# 113   6461    ...       6461    6461    6461    6461    6461               10
# 114   6461    ...       6461    6461    6461    6461    6430               36
# 115   6463    ...       6461    6461    6440    6461    6420               32
# 116   6461    ...       6463    6461    6461    6461    6461               42
# 117   6461    ...       6461    6461    6461    6461    6461               10
# 118   6461    ...       6461    6461    6220    6461    6461               43
# 119   6461    ...       6465    6430    6461    6461    4200               33
# 120   6461    ...       6463    6461    6461    6461    4500               34
# 121   6461    ...       6600    6540    6463    6463    6461               20
# 122   6461    ...       6420    6461    6461    6461    5400               43
# 123   6461    ...       6461    6461    6461    6461    6461               41
# 124   6461    ...       6461    6463    6463    6463    6461               35
# 125   6420    ...       6420    6461    6461    6465    3610               33
# 126   6461    ...       6461    6461    6461    6461    6450               34
# 127   6240    ...       6463    6420    6463    6420    6100               41
# 128   6461    ...       6461    6463    6461    6461    6461               20
# 129   6461    ...       6461    6461    6240    1300    6461               20
# 130   6461    ...       6465    6600    6463    1300    6520               20
# 131   6465    ...       6461    6461    6461    3500    6600               20
# 132   6461    ...       6463    6463    6461    6450    6461               44
# 133   6100    ...       6463    6430    6465    6465    6409               42
# 134   6461    ...       6463    6465    6463    6461    1400               34
# 135   6463    ...       6465    6420    6420    6461    3300               41
# 136   6463    ...       6409    6420    6450    6440    6461               41
#
#      Exam2  Final  original  semester
# 0      9.0   19.0      42.9        55
# 1     14.0   35.5      78.6        91
# 2     15.0   23.0      64.7        77
# 3     23.5   33.5      91.5        99
# 4     10.0   24.0      61.4        74
# 5      7.5   18.0      53.5        66
# 6     13.0   25.5      70.3        83
# 7     12.0   16.5      58.4        71
# 8     17.5   28.5      76.3        89
# 9      7.5    7.0      44.0        56
# 10    12.5   21.0      69.0        81
# 11     4.0    2.0      20.9        33
# 12     6.5   12.0      40.9        53
# 13     9.0   20.0      54.9        67
# 14    17.0   33.0      79.7        92
# 15     7.5   17.0      50.6        63
# 16     3.0   12.0      20.1        33
# 17    24.0   36.0      86.7        99
# 18    23.0   36.5      95.8        99
# 19    22.5   31.0      89.0        99
# 20    17.5   22.5      65.1        78
# 21     6.5    5.5      35.6        48
# 22    14.5   14.5      42.3        55
# 23    16.5   23.0      70.9        83
# 24    13.5   27.5      66.1        80
# 25    25.0   31.0      83.5        96
# 26    15.5   29.5      71.8        84
# 27     7.5   15.0      52.3        65
# 28    13.0   15.0      48.2        61
# 29    23.0   27.0      81.2        94
# ..     ...    ...       ...       ...
# 107   19.5   34.5      79.2        92
# 108   24.5   27.5      83.2        96
# 109    7.5   18.0      53.7        66
# 110    4.0   11.5      29.9        42
# 111   10.5   16.0      40.9        53
# 112    5.0   28.0      63.0        75
# 113    0.0    0.0      37.8        50
# 114    1.0   19.0      49.6        62
# 115    8.5   23.0      56.6        69
# 116   23.5   32.5      90.7        99
# 117    6.0    0.0      19.9        32
# 118   19.5   26.0      74.9        87
# 119    9.5   19.5      49.2        62
# 120    8.0    8.0      51.3        64
# 121   20.5   22.5      72.3        85
# 122   15.0   36.0      79.0        91
# 123   20.0   29.0      76.2        90
# 124    6.0   11.0      43.8        56
# 125   10.0   15.0      47.7        60
# 126    8.5   15.0      52.1        65
# 127   18.5   33.0      81.7        94
# 128   19.0   25.0      68.8        81
# 129   13.5   31.5      73.1        86
# 130   16.5   27.2      68.1        81
# 131    9.5   28.0      65.7        78
# 132   22.5   32.0      83.8        96
# 133   25.0   35.5      88.1        99
# 134    7.0   23.0      54.2        67
# 135   20.5   29.0      81.4        94
# 136   15.5   36.0      85.8        98
#
# [137 rows x 25 columns]

# %%
def layer_weight_MSE(a,b,layer):
    a = str(a)
    b = str(b)
#     print('compute [%s,%s] sim' % (a,b))
    layer_total_score = 0
    for i in range(layer):
        layer_sim = 1 if a[i]==b[i] else 0
#         print('\tlayer_sim=',layer_sim)
#         print('\tlayer-1-i=',layer-1-i)
        layer_score = layer_sim * pow(2,layer-1-i)
#         print('\tlayer_score=',layer_score)
        layer_total_score = layer_total_score +layer_score
    return layer_total_score/(pow(2,layer)-1)


# %matplotlib inline
def draw_bar(actual,merge,mean,std,prefix,student_id,week):

#     plt.figure(figsize=(10,8))
    plt.rcParams.update({'font.size': 12})
    df_merge = merge.sort_values(by='mean').groupby('mean').size().to_frame('size').reset_index()
    plt.errorbar( max(df_merge['size'])+5, mean, std, linestyle='None', marker='^')
    plt.errorbar( max(df_merge['size'])+5, actual, 0, linestyle='None', marker='^',color='r')
    # print(df_merge.columns)
    # df_merge.columns = ['grade','size']
    df_merge = pd.DataFrame(df_merge)
    df_merge['mean'].tolist()
    plt.barh(df_merge['mean'].tolist(),df_merge['size'].tolist(),facecolor = 'lightskyblue')
    plt.xlabel('count')
    plt.ylabel('grade')
    
    plt.savefig('../../applications/%s/data/image2/lmse_anthoer_%s_%s.png' % (prefix,student_id,week))
    plt.show()

# %%
# no 期中期末
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.metrics.pairwise import cosine_similarity

grade_torrance_df =[]
# for student_id in [102208082]:
# for student_id in [102205037]:

for student_id in rnn_input_data.head(27).id:
# student_id = 102208022
    print('===========================')
    print('student_id=',student_id)
    student = rnn_input_data[rnn_input_data.id == student_id].reset_index()
        # student_id = rnn_input_data.iloc[a].reset_index()
    seqgan_output_data.id=0
    print(student)

    boxplot_df = pd.DataFrame()
    data = []
    result = seqgan_output_data.loc[0].to_frame().T
    pre_result = seqgan_output_data.loc[0].to_frame().T
    for i in range(9,19):
        grade_torrance = []
        week_number = i
        
        week_column = 'week%s' % week_number
            #     student.loc[:, 'week1':week_column]
            #     print(student.loc[:, 'week1':week_column])
                # 取得前 10 周資料
        print('week=',week_column)

        
      
        prev = 0
        score = 500
        cluster_prob = pd.read_csv('../../applications/%s/data/cluster_level_more.csv'  % prefix)
        
        best_sim = 0
        cluster = 0
        seqgan_cluster = 0
        
        for j in range(0,seqgan_output_data.shape[0]):
            raw = student.loc[0, 'week1':week_column]
            seqgan = seqgan_output_data.loc[j, 'week1':week_column]
            
            lmse = 0
            for s in range(0,i):
                lmse = lmse + layer_weight_MSE(raw['week%s'%(s+1)],seqgan['week%s'%(s+1)],4)
#             print('lmse=',lmse)
            
#             if lmse > 0.9*i:
#                 row = seqgan_output_data.loc[j].to_frame().T
#                 row['lmse'] = lmse
#                 result = pd.concat([result,row])
#             print(seqgan)   
# result = result.drop(result.index[[0]])
# result
#             print(raw)
#             print(seqgan)
            #         print(sum(seqgan == raw))
                #         print(seqgan_output_data.loc[i, :])
#             count = sum(seqgan == raw)
#             similarity = cosine_similarity([seqgan], [raw])
#             print('similarity=',similarity)
#             if (count == week_number) | (count > prev):
#             if (similarity > 0.999):

            if (lmse > 0.95*i):
                row = seqgan_output_data.loc[j].to_frame().T
                row['lmse'] = lmse
                
                result = pd.concat([result,row])
                pre_result = result.copy()
            else:
                result = pre_result.copy()

        result = result.reset_index(drop=True)
        result = result.drop(result.index[[0]])
        result['cluster'] = result['clustered_label']

        rating_probs = result.sort_values(by='cluster').groupby('cluster').size().div(len(result))
        rating_count  = result.sort_values(by='cluster').groupby('cluster').size()
        print(rating_probs)
        print(rating_count)


        
        merge = pd.merge(result,cluster_prob, on='cluster')
        print(merge.sort_values(by='mean').groupby('mean').size())
        columns_names = ['0_9','10_19','20_29','30_39','40_49','50_59','60_69','70_79','80_89','90_99']
        
#         plt.figure(figsize=(16,9))
#         merge.sort_values(by='mean').groupby('mean').size().plot(kind = 'bar')
#         plt.show()
        
        grade_info = pd.DataFrame(data=merge['mean'].copy(),columns=['mean'])
        grade_info['week'] = week_number
        boxplot_df = pd.concat([boxplot_df,grade_info])
        predict_grade = np.mean(merge['mean'])
        predict_grade_std = np.std(merge['mean'])
        print('predict_grade=',predict_grade)
        print('predict_grade_std=',predict_grade_std)
        

        # real grade
        actual_grade = grade_df[grade_df.id == student_id].semester.values[0]
        midtern = grade_df[grade_df.id == student_id].semester.values[0]
        print('actual_grade=',actual_grade)
        grade_torrance.append(actual_grade)
        # predict grade
        grade_torrance.append(predict_grade)
        # torrance
        grade_torrance.append(predict_grade - actual_grade)
        grade_torrance.append(week_number)
        grade_torrance.append(student_id)
        grade_torrance_df.append(grade_torrance)
        
        draw_bar(actual_grade,merge,predict_grade,predict_grade_std,prefix,'%s_without_grade' % student_id,week_column)
        
        p_sum = 0 
        p_list = []
        for col in columns_names:
            p = merge[col].sum()/merge.shape[0]
            #         print('%s probability=' % col,p)
            p_list.append(p)
            p_sum = p_sum + p
        p_list.append(week_column)
        p_list.append(student_id)
            #     print('%s \n' % week_column,p_list)


        data.append(p_list)
    print(student_id)
#     print('grade:',grade_df[grade_df.id == student_id].semester.values[0])
    print(grade_torrance)
#     print(pd.DataFrame(data=grade_torrance_df,columns=['actual_grade','predict_grade','torrance','week','id']))
    boxplot_df.boxplot(column='mean',by=['week'],figsize=(16,9))
    plt.figure(figsize=(16,9))
    sns.violinplot('week','mean', data=boxplot_df)
    plt.savefig('../../applications/%s/data/image2/%s.png' % (prefix,student_id))
    plt.show()
    print(pd.DataFrame(data=data,columns=['0_9','10_19','20_29','30_39','40_49','50_59','60_69','70_79','80_89','90_99','week','id']))
    pd.DataFrame(data=data,columns=['0_9','10_19','20_29','30_39','40_49','50_59','60_69','70_79','80_89','90_99','week','id']).to_csv('../../applications/wm5-normalize-new-1/data/student_%s.csv' % student_id)

    all_grade_torrance_df = pd.DataFrame(data=grade_torrance_df,columns=['actual_grade','predict_grade','torrance','week','id'])
    all_grade_torrance_df.to_csv('../../applications/%s/data/all_grade_torrance_10000_lmse_without_grade.csv' % prefix)
# Out:
# ===========================
# student_id= 101208087
#    index         id  week1  week2  week3  week4  week5  week6  week7  week8  \
# 0      0  101208087   6461   6461   6461   6461   6461   6461   6461   6461
#
#         ...         week10  week11  week12  week13  week14  week15  week16  \
# 0       ...           6461    6461    5100    6461    6461    6461    6461
#
#    week17  week18  clustered_label
# 0    6461    6461               35
#
# [1 rows x 21 columns]
# week= week9
# clustered_label
# 20    0.322485
# 33    0.011834
# 34    0.124260
# 35    0.116864
# 36    0.010355
# 41    0.208580
# 42    0.063609
# 43    0.142012
# dtype: float64
# clustered_label
# 20    218
# 33      8
# 34     84
# 35     79
# 36      7
# 41    141
# 42     43
# 43     96
# dtype: int64
# mean
# 55.44     79
# 61.50      8
# 62.00      7
# 65.86     84
# 80.06    218
# 89.44     96
# 92.86    141
# 99.00     43
# dtype: int64
# predict_grade= 80.21831360946805
# predict_grade_std= 13.145646121396508
# actual_grade= 55
# C:\Users\soslab\Anaconda3\lib\site-packages\pandas\core\indexes\api.py:107: RuntimeWarning: unorderable types: str() < int(), sort order is undefined for incomparable objects
#   result = result.union(other)
# week= week10
# clustered_label
# 20.0    0.551020
# 34.0    0.357143
# 36.0    0.035714
# 42.0    0.056122
# dtype: float64
# clustered_label
# 20.0    108
# 34.0     70
# 36.0      7
# 42.0     11
# dtype: int64
# mean
# 62.00      7
# 65.86     70
# 80.06    108
# 99.00     11
# dtype: int64
# predict_grade= 75.40653061224519
# predict_grade_std= 9.063148200834373
# actual_grade= 55
# week= week11
# clustered_label
# 20.0    1.0
# dtype: float64
# clustered_label
# 20.0    48
# dtype: int64
# mean
# 80.06    48
# dtype: int64
# predict_grade= 80.05999999999996
# predict_grade_std= 4.263256414560601e-14
# actual_grade= 55
# week= week12
# Series([], dtype: float64)
# Series([], dtype: int64)
# Series([], dtype: int64)
# predict_grade= nan
# predict_grade_std= nan
# actual_grade= 55
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-9fbe1c0bd5fa> in <module>()
#     133         grade_torrance_df.append(grade_torrance)
#     134
# --> 135         draw_bar(actual_grade,merge,predict_grade,predict_grade_std,prefix,'%s_without_grade' % student_id,week_column)
#     136
#     137         p_sum = 0
#
# <ipython-input-6-ed643956c603> in draw_bar(actual, merge, mean, std, prefix, student_id, week)
#      20     plt.rcParams.update({'font.size': 12})
#      21     df_merge = merge.sort_values(by='mean').groupby('mean').size().to_frame('size').reset_index()
# ---> 22     plt.errorbar( max(df_merge['size'])+5, mean, std, linestyle='None', marker='^')
#      23     plt.errorbar( max(df_merge['size'])+5, actual, 0, linestyle='None', marker='^',color='r')
#      24     # print(df_merge.columns)
#
# ValueError: max() arg is an empty sequence

# %%
mle_std

# %%
all_grade_torrance_df.to_csv('../../applications/%s/data/all_grade_torrance_10000_lmse_without_grade.csv' % prefix)
all_grade_torrance_df = pd.read_csv('../../applications/%s/data/all_grade_torrance_10000_lmse_without_grade.csv' % prefix)
all_grade_torrance_df
